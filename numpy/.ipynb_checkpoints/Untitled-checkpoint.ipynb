# %%
# %matplotlib inline

import matplotlib.pyplot as plt 
import numpy as np 

salario = np.array([100, 200, 300, 500, 400, 150])
print(salario)

plt.plot(salario, c='Red', ls='--', marker='s', ms=7)
plt.show()
# Out:
# [100 200 300 500 400 150]
